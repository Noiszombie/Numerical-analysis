# %%
import math
def Chebyshev(variable, power):
    T = math.cos(power * math.acos(variable))
    return T

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
# Первая область рисования (мультиокно 1)
ax = fig.add_subplot(211)
x = []
y = []
colors = {0: 'blue', 1: 'red', 2: 'yellow', 3: 'green', 4: 'brown', 5: 'black'}
for n in range (6):
    for i in range(201):
        if i < 100:
            x.append((i/100) - 1)
            y.append(Chebyshev(x[i],n))
        else:
            x.append((i/100) - 1)
            y.append(Chebyshev(x[i],n))
    ax.plot(x, y, color = colors[n])
    x.clear()
    y.clear()
xax = ax.xaxis
yax = ax.yaxis
xlocs = xax.get_ticklocs()
print ('Major X-ticks locations:', xlocs)
xlabels = xax.get_ticklabels()
print ('Major X-ticks labels:', xlabels)
xlines = xax.get_ticklines()
print ('Major X-ticks tick lines:', xlines)
# Линии вспомогательной сетки (главные деления) только по оси абсцисс
xax.grid(True)
yax.grid(True)

for label in xlabels:
    # цвет подписи деленений оси OX
    label.set_color('red')
    # поворот подписей деленений оси OX 
    label.set_rotation(45)
    # размер шрифта подписей делений оси OX 
    label.set_fontsize(14)


#print ('Lines on the axes:', type(line), line)
plt.show()
# Out:
# Major X-ticks locations: [-1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75  1.    1.25]
# Major X-ticks labels: <a list of 11 Text major ticklabel objects>
# Major X-ticks tick lines: <a list of 22 Line2D ticklines objects>
